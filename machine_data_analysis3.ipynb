# %%
# Загрузка зависимостей
import numpy
import pandas
import matplotlib.pyplot as plt
import keras
from keras.models import Sequential
from keras.layers import Dense
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from scipy import stats
from statsmodels.graphics.gofplots import qqplot

# %%
# Загрузка подготовленного набора данных
dataset = pandas.read_csv('prepared_data.csv') # Убедиться в правильности пути к файлу!
dataset.head(10) # Вывод первых 10 строк
# Out:
#    Unnamed: 0      MMIN     CHMAX         2         4         5         6  \
# 0           0  0.251074  1.000000  0.489650  0.730638  1.000000  0.894427
# 1           1  0.874463  0.676123  0.131078  1.000000  0.421637  0.632456
# 2           2  0.874463  0.676123  0.131078  1.000000  0.421637  0.632456
# 3           3  0.874463  0.676123  0.131078  1.000000  0.421637  0.632456
# 4           4  0.874463  0.478091  0.131078  0.888465  0.421637  0.632456
# 5           5  0.874463  0.676123  0.104278  1.000000  0.596285  0.632456
# 6           6  1.000000  0.676123  0.074188  1.000000  0.596285  0.894427
# 7           7  1.000000  0.676123  0.074188  1.000000  0.596285  0.894427
# 8           8  1.000000  0.676123  0.074188  1.000000  0.596285  0.894427
# 9           9  1.000000  0.956183  0.074188  1.000000  0.843274  1.000000
#
#           8
# 0  0.759257
# 1  0.825801
# 2  0.782136
# 3  0.728689
# 4  0.671211
# 5  0.862138
# 6  0.893257
# 7  0.955579
# 8  1.000000
# 9  1.000000

# %%
Xx = dataset.iloc[:, [*range(1,5)]]
Xx.head(10)
# Out:
#        MMIN     CHMAX         2         4
# 0  0.251074  1.000000  0.489650  0.730638
# 1  0.874463  0.676123  0.131078  1.000000
# 2  0.874463  0.676123  0.131078  1.000000
# 3  0.874463  0.676123  0.131078  1.000000
# 4  0.874463  0.478091  0.131078  0.888465
# 5  0.874463  0.676123  0.104278  1.000000
# 6  1.000000  0.676123  0.074188  1.000000
# 7  1.000000  0.676123  0.074188  1.000000
# 8  1.000000  0.676123  0.074188  1.000000
# 9  1.000000  0.956183  0.074188  1.000000

# %%
# Выделение входных и выходных параметров:
# Выходной параметр - значение столбца обработанного набора данных, соответсвующее столбцу №8 из первоначального набора данных (machine.data.csv).
# Входные параметры - все остальные столбцы обработанного набора данных.
# Используем .values, чтобы индексы не попали в новые переменные и в дальнейшем не мешали нам, например, при построении графиков.
X = dataset.iloc[:, [*range(1,5)]].values
Y = dataset['8'].values

# Обратите внимание на структуру вашего обработанного файлы и измените индексы, если нужно.

# %%
# Разделение данных на обучающую и тестовую выборки:
# Используем метод train_test_split библиотеки sklearn.
# Он разделяет заданные массивы входных и выходных параметров на две части каждый.
# Значение test_size определяет долю тестовой выборки в исходных данных.
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2)

# %%
# Задаем параметры структуры нейронной сети.

# Количество нейронов во входном слое должно быть равно количеству входных параметров.
input_layer_size = 4

# Количество нейронов в каждом скрытом слое и количество таких слоёв могут быть выбраны произвольно.
# Увеличение числа нейронов относительно предыдущего слоя позволяет лучше обрабатывать отдельные примеры.
# Уменьшение числа нейронов относительно предыдущего слоя позволяет обощать информацию и выводить новые правила.
# Увеличение числа слоёв помогает сети работать как более сложная функция.
first_hidden_layer_size = 50
second_hidden_layer_size = 30

# Количество нейронов в выходном слое должно быть равно количеству выходных параметров.
output_layer_size = 1
# Параметры обучения нейронной сети: количество эпох и размер батча.
epochs_number = 100
batch_size = 16

# %%
# Создание нейронной сети прямого распространения, пока она пустая, т.е. не содержит слоёв и нейронов.
model = Sequential()

# Входной слой и первый скрытый слой, функция активации - ReLU
model.add(Dense(first_hidden_layer_size, input_dim=input_layer_size, activation='relu'))

# Второй скрытый слой, функция активации - ReLU
model.add(Dense(second_hidden_layer_size, activation='relu'))

# Выходной слой, функция активации - линейная, т.к. решается задача регрессии.
model.add(Dense(output_layer_size, activation='linear'))

# %%
# Обзор нейронной сети, теперь в ней есть слои и нейроны.
# Если внимательно посмотреть на количество параметров, т.е. связей между нейронами, то можно увидеть, что автоматически добавлены нейроны смещения.
model.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_23 (Dense)             (None, 50)                250
# _________________________________________________________________
# dense_24 (Dense)             (None, 30)                1530
# _________________________________________________________________
# dense_25 (Dense)             (None, 1)                 31
# =================================================================
# Total params: 1,811
# Trainable params: 1,811
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Настройка нейронной сети.
# Функция потерь (loss) - среднеквадратическая ошибка.
# Оптимизатор (optimizer) - adam (в настоящий момент - это стандартный оптимизатор).
# Указываем метрики средняя абсолютная ошибка (mean_absolute_error) и среднеквадратическая ошиба (mean_squared_error) для дальнейшего анализа.
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_absolute_error', 'mean_squared_error'])

# %%
# Обучение нейронной сети.
# На вход передаем обучающие и тестовые выборки, количество эпох и размер батча.
# На выходе получаем объект с историей обучения, который далее будем анализировать.
history = model.fit(X_train, Y_train, validation_data = (X_test,Y_test), epochs=epochs_number, batch_size=batch_size)
# Out:
# Train on 167 samples, validate on 42 samples
# Epoch 1/100
# 167/167 [==============================] - 0s 1ms/step - loss: 0.1335 - mean_absolute_error: 0.3145 - mean_squared_error: 0.1335 - val_loss: 0.0360 - val_mean_absolute_error: 0.1528 - val_mean_squared_error: 0.0360
# Epoch 2/100
# 167/167 [==============================] - 0s 275us/step - loss: 0.0284 - mean_absolute_error: 0.1298 - mean_squared_error: 0.0284 - val_loss: 0.0158 - val_mean_absolute_error: 0.1017 - val_mean_squared_error: 0.0158
# Epoch 3/100
# 167/167 [==============================] - 0s 220us/step - loss: 0.0212 - mean_absolute_error: 0.1211 - mean_squared_error: 0.0212 - val_loss: 0.0199 - val_mean_absolute_error: 0.1161 - val_mean_squared_error: 0.0199
# Epoch 4/100
# 167/167 [==============================] - 0s 213us/step - loss: 0.0171 - mean_absolute_error: 0.1081 - mean_squared_error: 0.0171 - val_loss: 0.0118 - val_mean_absolute_error: 0.0871 - val_mean_squared_error: 0.0118
# Epoch 5/100
# 167/167 [==============================] - 0s 314us/step - loss: 0.0141 - mean_absolute_error: 0.0946 - mean_squared_error: 0.0141 - val_loss: 0.0102 - val_mean_absolute_error: 0.0825 - val_mean_squared_error: 0.0102
# Epoch 6/100
# 167/167 [==============================] - 0s 217us/step - loss: 0.0123 - mean_absolute_error: 0.0881 - mean_squared_error: 0.0123 - val_loss: 0.0109 - val_mean_absolute_error: 0.0821 - val_mean_squared_error: 0.0109
# Epoch 7/100
# 167/167 [==============================] - 0s 325us/step - loss: 0.0125 - mean_absolute_error: 0.0883 - mean_squared_error: 0.0125 - val_loss: 0.0112 - val_mean_absolute_error: 0.0817 - val_mean_squared_error: 0.0112
# Epoch 8/100
# 167/167 [==============================] - 0s 221us/step - loss: 0.0119 - mean_absolute_error: 0.0861 - mean_squared_error: 0.0119 - val_loss: 0.0094 - val_mean_absolute_error: 0.0787 - val_mean_squared_error: 0.0094
# Epoch 9/100
# 167/167 [==============================] - 0s 334us/step - loss: 0.0114 - mean_absolute_error: 0.0837 - mean_squared_error: 0.0114 - val_loss: 0.0101 - val_mean_absolute_error: 0.0794 - val_mean_squared_error: 0.0101
# Epoch 10/100
# 167/167 [==============================] - 0s 214us/step - loss: 0.0117 - mean_absolute_error: 0.0844 - mean_squared_error: 0.0117 - val_loss: 0.0099 - val_mean_absolute_error: 0.0787 - val_mean_squared_error: 0.0099
# Epoch 11/100
# 167/167 [==============================] - 0s 353us/step - loss: 0.0110 - mean_absolute_error: 0.0819 - mean_squared_error: 0.0110 - val_loss: 0.0090 - val_mean_absolute_error: 0.0773 - val_mean_squared_error: 0.0090
# Epoch 12/100
# 167/167 [==============================] - 0s 198us/step - loss: 0.0110 - mean_absolute_error: 0.0820 - mean_squared_error: 0.0110 - val_loss: 0.0090 - val_mean_absolute_error: 0.0768 - val_mean_squared_error: 0.0090
# Epoch 13/100
# 167/167 [==============================] - 0s 341us/step - loss: 0.0109 - mean_absolute_error: 0.0819 - mean_squared_error: 0.0109 - val_loss: 0.0089 - val_mean_absolute_error: 0.0760 - val_mean_squared_error: 0.0089
# Epoch 14/100
# 167/167 [==============================] - 0s 203us/step - loss: 0.0111 - mean_absolute_error: 0.0824 - mean_squared_error: 0.0111 - val_loss: 0.0095 - val_mean_absolute_error: 0.0768 - val_mean_squared_error: 0.0095
# Epoch 15/100
# 167/167 [==============================] - 0s 293us/step - loss: 0.0112 - mean_absolute_error: 0.0828 - mean_squared_error: 0.0112 - val_loss: 0.0083 - val_mean_absolute_error: 0.0753 - val_mean_squared_error: 0.0083
# Epoch 16/100
# 167/167 [==============================] - 0s 221us/step - loss: 0.0107 - mean_absolute_error: 0.0802 - mean_squared_error: 0.0107 - val_loss: 0.0092 - val_mean_absolute_error: 0.0755 - val_mean_squared_error: 0.0092
# Epoch 17/100
# 167/167 [==============================] - 0s 260us/step - loss: 0.0105 - mean_absolute_error: 0.0799 - mean_squared_error: 0.0105 - val_loss: 0.0082 - val_mean_absolute_error: 0.0742 - val_mean_squared_error: 0.0082
# Epoch 18/100
# 167/167 [==============================] - 0s 163us/step - loss: 0.0103 - mean_absolute_error: 0.0787 - mean_squared_error: 0.0103 - val_loss: 0.0084 - val_mean_absolute_error: 0.0737 - val_mean_squared_error: 0.0084
# Epoch 19/100
# 167/167 [==============================] - 0s 167us/step - loss: 0.0102 - mean_absolute_error: 0.0785 - mean_squared_error: 0.0102 - val_loss: 0.0080 - val_mean_absolute_error: 0.0736 - val_mean_squared_error: 0.0080
# Epoch 20/100
# 167/167 [==============================] - 0s 281us/step - loss: 0.0102 - mean_absolute_error: 0.0784 - mean_squared_error: 0.0102 - val_loss: 0.0083 - val_mean_absolute_error: 0.0731 - val_mean_squared_error: 0.0083
# Epoch 21/100
# 167/167 [==============================] - 0s 191us/step - loss: 0.0102 - mean_absolute_error: 0.0787 - mean_squared_error: 0.0102 - val_loss: 0.0080 - val_mean_absolute_error: 0.0730 - val_mean_squared_error: 0.0080
# Epoch 22/100
# 167/167 [==============================] - 0s 263us/step - loss: 0.0101 - mean_absolute_error: 0.0780 - mean_squared_error: 0.0101 - val_loss: 0.0083 - val_mean_absolute_error: 0.0723 - val_mean_squared_error: 0.0083
# Epoch 23/100
# 167/167 [==============================] - 0s 171us/step - loss: 0.0101 - mean_absolute_error: 0.0786 - mean_squared_error: 0.0101 - val_loss: 0.0080 - val_mean_absolute_error: 0.0720 - val_mean_squared_error: 0.0080
# Epoch 24/100
# 167/167 [==============================] - 0s 190us/step - loss: 0.0101 - mean_absolute_error: 0.0787 - mean_squared_error: 0.0101 - val_loss: 0.0079 - val_mean_absolute_error: 0.0718 - val_mean_squared_error: 0.0079
# Epoch 25/100
# 167/167 [==============================] - 0s 286us/step - loss: 0.0100 - mean_absolute_error: 0.0777 - mean_squared_error: 0.0100 - val_loss: 0.0081 - val_mean_absolute_error: 0.0717 - val_mean_squared_error: 0.0081
# Epoch 26/100
# 167/167 [==============================] - 0s 137us/step - loss: 0.0101 - mean_absolute_error: 0.0785 - mean_squared_error: 0.0101 - val_loss: 0.0079 - val_mean_absolute_error: 0.0716 - val_mean_squared_error: 0.0079
# Epoch 27/100
# 167/167 [==============================] - 0s 262us/step - loss: 0.0099 - mean_absolute_error: 0.0776 - mean_squared_error: 0.0099 - val_loss: 0.0079 - val_mean_absolute_error: 0.0711 - val_mean_squared_error: 0.0079
# Epoch 28/100
# 167/167 [==============================] - 0s 171us/step - loss: 0.0100 - mean_absolute_error: 0.0779 - mean_squared_error: 0.0100 - val_loss: 0.0079 - val_mean_absolute_error: 0.0711 - val_mean_squared_error: 0.0079
# Epoch 29/100
# 167/167 [==============================] - 0s 129us/step - loss: 0.0098 - mean_absolute_error: 0.0770 - mean_squared_error: 0.0098 - val_loss: 0.0081 - val_mean_absolute_error: 0.0711 - val_mean_squared_error: 0.0081
# Epoch 30/100
# 167/167 [==============================] - 0s 262us/step - loss: 0.0098 - mean_absolute_error: 0.0769 - mean_squared_error: 0.0098 - val_loss: 0.0078 - val_mean_absolute_error: 0.0706 - val_mean_squared_error: 0.0078
# Epoch 31/100
# 167/167 [==============================] - 0s 210us/step - loss: 0.0098 - mean_absolute_error: 0.0779 - mean_squared_error: 0.0098 - val_loss: 0.0080 - val_mean_absolute_error: 0.0706 - val_mean_squared_error: 0.0080
# Epoch 32/100
# 167/167 [==============================] - 0s 202us/step - loss: 0.0098 - mean_absolute_error: 0.0774 - mean_squared_error: 0.0098 - val_loss: 0.0077 - val_mean_absolute_error: 0.0702 - val_mean_squared_error: 0.0077
# Epoch 33/100
# 167/167 [==============================] - 0s 214us/step - loss: 0.0098 - mean_absolute_error: 0.0769 - mean_squared_error: 0.0098 - val_loss: 0.0079 - val_mean_absolute_error: 0.0704 - val_mean_squared_error: 0.0079
# Epoch 34/100
# 167/167 [==============================] - 0s 214us/step - loss: 0.0099 - mean_absolute_error: 0.0780 - mean_squared_error: 0.0099 - val_loss: 0.0078 - val_mean_absolute_error: 0.0702 - val_mean_squared_error: 0.0078
# Epoch 35/100
# 167/167 [==============================] - 0s 282us/step - loss: 0.0097 - mean_absolute_error: 0.0771 - mean_squared_error: 0.0097 - val_loss: 0.0077 - val_mean_absolute_error: 0.0700 - val_mean_squared_error: 0.0077
# Epoch 36/100
# 167/167 [==============================] - 0s 214us/step - loss: 0.0096 - mean_absolute_error: 0.0767 - mean_squared_error: 0.0096 - val_loss: 0.0078 - val_mean_absolute_error: 0.0699 - val_mean_squared_error: 0.0078
# Epoch 37/100
# 167/167 [==============================] - 0s 202us/step - loss: 0.0098 - mean_absolute_error: 0.0775 - mean_squared_error: 0.0098 - val_loss: 0.0082 - val_mean_absolute_error: 0.0705 - val_mean_squared_error: 0.0082
# Epoch 38/100
# 167/167 [==============================] - 0s 214us/step - loss: 0.0097 - mean_absolute_error: 0.0767 - mean_squared_error: 0.0097 - val_loss: 0.0077 - val_mean_absolute_error: 0.0696 - val_mean_squared_error: 0.0077
# Epoch 39/100
# 167/167 [==============================] - 0s 184us/step - loss: 0.0098 - mean_absolute_error: 0.0775 - mean_squared_error: 0.0098 - val_loss: 0.0078 - val_mean_absolute_error: 0.0695 - val_mean_squared_error: 0.0078
# Epoch 40/100
# 167/167 [==============================] - 0s 307us/step - loss: 0.0101 - mean_absolute_error: 0.0786 - mean_squared_error: 0.0101 - val_loss: 0.0076 - val_mean_absolute_error: 0.0694 - val_mean_squared_error: 0.0076
# Epoch 41/100
# 167/167 [==============================] - 0s 192us/step - loss: 0.0098 - mean_absolute_error: 0.0774 - mean_squared_error: 0.0098 - val_loss: 0.0077 - val_mean_absolute_error: 0.0694 - val_mean_squared_error: 0.0077
# Epoch 42/100
# 167/167 [==============================] - 0s 222us/step - loss: 0.0099 - mean_absolute_error: 0.0772 - mean_squared_error: 0.0099 - val_loss: 0.0077 - val_mean_absolute_error: 0.0692 - val_mean_squared_error: 0.0077
# Epoch 43/100
# 167/167 [==============================] - 0s 213us/step - loss: 0.0095 - mean_absolute_error: 0.0757 - mean_squared_error: 0.0095 - val_loss: 0.0084 - val_mean_absolute_error: 0.0708 - val_mean_squared_error: 0.0084
# Epoch 44/100
# 167/167 [==============================] - 0s 140us/step - loss: 0.0096 - mean_absolute_error: 0.0759 - mean_squared_error: 0.0096 - val_loss: 0.0076 - val_mean_absolute_error: 0.0690 - val_mean_squared_error: 0.0076
# Epoch 45/100
# 167/167 [==============================] - 0s 241us/step - loss: 0.0095 - mean_absolute_error: 0.0761 - mean_squared_error: 0.0095 - val_loss: 0.0082 - val_mean_absolute_error: 0.0698 - val_mean_squared_error: 0.0082
# Epoch 46/100
# 167/167 [==============================] - 0s 202us/step - loss: 0.0096 - mean_absolute_error: 0.0774 - mean_squared_error: 0.0096 - val_loss: 0.0076 - val_mean_absolute_error: 0.0689 - val_mean_squared_error: 0.0076
# Epoch 47/100
# 167/167 [==============================] - 0s 230us/step - loss: 0.0095 - mean_absolute_error: 0.0764 - mean_squared_error: 0.0095 - val_loss: 0.0079 - val_mean_absolute_error: 0.0692 - val_mean_squared_error: 0.0079
# Epoch 48/100
# 167/167 [==============================] - 0s 217us/step - loss: 0.0094 - mean_absolute_error: 0.0760 - mean_squared_error: 0.0094 - val_loss: 0.0080 - val_mean_absolute_error: 0.0694 - val_mean_squared_error: 0.0080
# Epoch 49/100
# 167/167 [==============================] - 0s 229us/step - loss: 0.0094 - mean_absolute_error: 0.0758 - mean_squared_error: 0.0094 - val_loss: 0.0078 - val_mean_absolute_error: 0.0688 - val_mean_squared_error: 0.0078
# Epoch 50/100
# 167/167 [==============================] - 0s 281us/step - loss: 0.0094 - mean_absolute_error: 0.0754 - mean_squared_error: 0.0094 - val_loss: 0.0075 - val_mean_absolute_error: 0.0684 - val_mean_squared_error: 0.0075
# Epoch 51/100
# 167/167 [==============================] - 0s 200us/step - loss: 0.0094 - mean_absolute_error: 0.0755 - mean_squared_error: 0.0094 - val_loss: 0.0082 - val_mean_absolute_error: 0.0695 - val_mean_squared_error: 0.0082
# Epoch 52/100
# 167/167 [==============================] - 0s 245us/step - loss: 0.0095 - mean_absolute_error: 0.0768 - mean_squared_error: 0.0095 - val_loss: 0.0076 - val_mean_absolute_error: 0.0683 - val_mean_squared_error: 0.0076
# Epoch 53/100
# 167/167 [==============================] - 0s 183us/step - loss: 0.0095 - mean_absolute_error: 0.0762 - mean_squared_error: 0.0095 - val_loss: 0.0078 - val_mean_absolute_error: 0.0684 - val_mean_squared_error: 0.0078
# Epoch 54/100
# 167/167 [==============================] - 0s 190us/step - loss: 0.0092 - mean_absolute_error: 0.0750 - mean_squared_error: 0.0092 - val_loss: 0.0078 - val_mean_absolute_error: 0.0683 - val_mean_squared_error: 0.0078
# Epoch 55/100
# 167/167 [==============================] - 0s 261us/step - loss: 0.0092 - mean_absolute_error: 0.0750 - mean_squared_error: 0.0092 - val_loss: 0.0077 - val_mean_absolute_error: 0.0681 - val_mean_squared_error: 0.0077
# Epoch 56/100
# 167/167 [==============================] - 0s 179us/step - loss: 0.0092 - mean_absolute_error: 0.0752 - mean_squared_error: 0.0092 - val_loss: 0.0078 - val_mean_absolute_error: 0.0682 - val_mean_squared_error: 0.0078
# Epoch 57/100
# 167/167 [==============================] - 0s 256us/step - loss: 0.0093 - mean_absolute_error: 0.0752 - mean_squared_error: 0.0093 - val_loss: 0.0081 - val_mean_absolute_error: 0.0691 - val_mean_squared_error: 0.0081
# Epoch 58/100
# 167/167 [==============================] - 0s 154us/step - loss: 0.0093 - mean_absolute_error: 0.0755 - mean_squared_error: 0.0093 - val_loss: 0.0076 - val_mean_absolute_error: 0.0678 - val_mean_squared_error: 0.0076
# Epoch 59/100
# 167/167 [==============================] - 0s 202us/step - loss: 0.0094 - mean_absolute_error: 0.0755 - mean_squared_error: 0.0094 - val_loss: 0.0082 - val_mean_absolute_error: 0.0687 - val_mean_squared_error: 0.0082
# Epoch 60/100
# 167/167 [==============================] - 0s 250us/step - loss: 0.0094 - mean_absolute_error: 0.0764 - mean_squared_error: 0.0094 - val_loss: 0.0075 - val_mean_absolute_error: 0.0677 - val_mean_squared_error: 0.0075
# Epoch 61/100
# 167/167 [==============================] - 0s 174us/step - loss: 0.0097 - mean_absolute_error: 0.0771 - mean_squared_error: 0.0097 - val_loss: 0.0084 - val_mean_absolute_error: 0.0699 - val_mean_squared_error: 0.0084
# Epoch 62/100
# 167/167 [==============================] - 0s 189us/step - loss: 0.0094 - mean_absolute_error: 0.0761 - mean_squared_error: 0.0094 - val_loss: 0.0077 - val_mean_absolute_error: 0.0676 - val_mean_squared_error: 0.0077
# Epoch 63/100
# 167/167 [==============================] - 0s 219us/step - loss: 0.0092 - mean_absolute_error: 0.0753 - mean_squared_error: 0.0092 - val_loss: 0.0080 - val_mean_absolute_error: 0.0682 - val_mean_squared_error: 0.0080
# Epoch 64/100
# 167/167 [==============================] - 0s 194us/step - loss: 0.0091 - mean_absolute_error: 0.0745 - mean_squared_error: 0.0091 - val_loss: 0.0077 - val_mean_absolute_error: 0.0678 - val_mean_squared_error: 0.0077
# Epoch 65/100
# 167/167 [==============================] - 0s 273us/step - loss: 0.0092 - mean_absolute_error: 0.0748 - mean_squared_error: 0.0092 - val_loss: 0.0077 - val_mean_absolute_error: 0.0679 - val_mean_squared_error: 0.0077
# Epoch 66/100
# 167/167 [==============================] - 0s 238us/step - loss: 0.0091 - mean_absolute_error: 0.0742 - mean_squared_error: 0.0091 - val_loss: 0.0079 - val_mean_absolute_error: 0.0686 - val_mean_squared_error: 0.0079
# Epoch 67/100
# 167/167 [==============================] - 0s 222us/step - loss: 0.0091 - mean_absolute_error: 0.0743 - mean_squared_error: 0.0091 - val_loss: 0.0079 - val_mean_absolute_error: 0.0679 - val_mean_squared_error: 0.0079
# Epoch 68/100
# 167/167 [==============================] - 0s 207us/step - loss: 0.0091 - mean_absolute_error: 0.0747 - mean_squared_error: 0.0091 - val_loss: 0.0078 - val_mean_absolute_error: 0.0677 - val_mean_squared_error: 0.0078
# Epoch 69/100
# 167/167 [==============================] - 0s 195us/step - loss: 0.0090 - mean_absolute_error: 0.0741 - mean_squared_error: 0.0090 - val_loss: 0.0081 - val_mean_absolute_error: 0.0682 - val_mean_squared_error: 0.0081
# Epoch 70/100
# 167/167 [==============================] - 0s 231us/step - loss: 0.0090 - mean_absolute_error: 0.0742 - mean_squared_error: 0.0090 - val_loss: 0.0079 - val_mean_absolute_error: 0.0683 - val_mean_squared_error: 0.0079
# Epoch 71/100
# 167/167 [==============================] - 0s 190us/step - loss: 0.0090 - mean_absolute_error: 0.0736 - mean_squared_error: 0.0090 - val_loss: 0.0077 - val_mean_absolute_error: 0.0674 - val_mean_squared_error: 0.0077
# Epoch 72/100
# 167/167 [==============================] - 0s 218us/step - loss: 0.0091 - mean_absolute_error: 0.0745 - mean_squared_error: 0.0091 - val_loss: 0.0077 - val_mean_absolute_error: 0.0671 - val_mean_squared_error: 0.0077
# Epoch 73/100
# 167/167 [==============================] - 0s 219us/step - loss: 0.0090 - mean_absolute_error: 0.0738 - mean_squared_error: 0.0090 - val_loss: 0.0078 - val_mean_absolute_error: 0.0675 - val_mean_squared_error: 0.0078
# Epoch 74/100
# 167/167 [==============================] - 0s 200us/step - loss: 0.0091 - mean_absolute_error: 0.0749 - mean_squared_error: 0.0091 - val_loss: 0.0077 - val_mean_absolute_error: 0.0674 - val_mean_squared_error: 0.0077
# Epoch 75/100
# 167/167 [==============================] - 0s 265us/step - loss: 0.0090 - mean_absolute_error: 0.0748 - mean_squared_error: 0.0090 - val_loss: 0.0075 - val_mean_absolute_error: 0.0671 - val_mean_squared_error: 0.0075
# Epoch 76/100
# 167/167 [==============================] - 0s 165us/step - loss: 0.0092 - mean_absolute_error: 0.0750 - mean_squared_error: 0.0092 - val_loss: 0.0079 - val_mean_absolute_error: 0.0678 - val_mean_squared_error: 0.0079
# Epoch 77/100
# 167/167 [==============================] - 0s 274us/step - loss: 0.0089 - mean_absolute_error: 0.0734 - mean_squared_error: 0.0089 - val_loss: 0.0077 - val_mean_absolute_error: 0.0666 - val_mean_squared_error: 0.0077
# Epoch 78/100
# 167/167 [==============================] - 0s 226us/step - loss: 0.0089 - mean_absolute_error: 0.0736 - mean_squared_error: 0.0089 - val_loss: 0.0082 - val_mean_absolute_error: 0.0678 - val_mean_squared_error: 0.0082
# Epoch 79/100
# 167/167 [==============================] - 0s 209us/step - loss: 0.0090 - mean_absolute_error: 0.0735 - mean_squared_error: 0.0090 - val_loss: 0.0076 - val_mean_absolute_error: 0.0672 - val_mean_squared_error: 0.0076
# Epoch 80/100
# 167/167 [==============================] - 0s 216us/step - loss: 0.0089 - mean_absolute_error: 0.0738 - mean_squared_error: 0.0089 - val_loss: 0.0083 - val_mean_absolute_error: 0.0679 - val_mean_squared_error: 0.0083
# Epoch 81/100
# 167/167 [==============================] - 0s 191us/step - loss: 0.0089 - mean_absolute_error: 0.0732 - mean_squared_error: 0.0089 - val_loss: 0.0080 - val_mean_absolute_error: 0.0675 - val_mean_squared_error: 0.0080
# Epoch 82/100
# 167/167 [==============================] - 0s 278us/step - loss: 0.0087 - mean_absolute_error: 0.0727 - mean_squared_error: 0.0087 - val_loss: 0.0076 - val_mean_absolute_error: 0.0663 - val_mean_squared_error: 0.0076
# Epoch 83/100
# 167/167 [==============================] - 0s 223us/step - loss: 0.0089 - mean_absolute_error: 0.0735 - mean_squared_error: 0.0089 - val_loss: 0.0080 - val_mean_absolute_error: 0.0671 - val_mean_squared_error: 0.0080
# Epoch 84/100
# 167/167 [==============================] - 0s 217us/step - loss: 0.0087 - mean_absolute_error: 0.0729 - mean_squared_error: 0.0087 - val_loss: 0.0079 - val_mean_absolute_error: 0.0669 - val_mean_squared_error: 0.0079
# Epoch 85/100
# 167/167 [==============================] - 0s 210us/step - loss: 0.0092 - mean_absolute_error: 0.0753 - mean_squared_error: 0.0092 - val_loss: 0.0082 - val_mean_absolute_error: 0.0680 - val_mean_squared_error: 0.0082
# Epoch 86/100
# 167/167 [==============================] - 0s 256us/step - loss: 0.0090 - mean_absolute_error: 0.0742 - mean_squared_error: 0.0090 - val_loss: 0.0075 - val_mean_absolute_error: 0.0663 - val_mean_squared_error: 0.0075
# Epoch 87/100
# 167/167 [==============================] - 0s 192us/step - loss: 0.0089 - mean_absolute_error: 0.0735 - mean_squared_error: 0.0089 - val_loss: 0.0078 - val_mean_absolute_error: 0.0663 - val_mean_squared_error: 0.0078
# Epoch 88/100
# 167/167 [==============================] - 0s 215us/step - loss: 0.0087 - mean_absolute_error: 0.0729 - mean_squared_error: 0.0087 - val_loss: 0.0077 - val_mean_absolute_error: 0.0671 - val_mean_squared_error: 0.0077
# Epoch 89/100
# 167/167 [==============================] - 0s 292us/step - loss: 0.0088 - mean_absolute_error: 0.0723 - mean_squared_error: 0.0088 - val_loss: 0.0077 - val_mean_absolute_error: 0.0663 - val_mean_squared_error: 0.0077
# Epoch 90/100
# 167/167 [==============================] - 0s 177us/step - loss: 0.0089 - mean_absolute_error: 0.0728 - mean_squared_error: 0.0089 - val_loss: 0.0081 - val_mean_absolute_error: 0.0670 - val_mean_squared_error: 0.0081
# Epoch 91/100
# 167/167 [==============================] - 0s 205us/step - loss: 0.0086 - mean_absolute_error: 0.0722 - mean_squared_error: 0.0086 - val_loss: 0.0077 - val_mean_absolute_error: 0.0661 - val_mean_squared_error: 0.0077
# Epoch 92/100
# 167/167 [==============================] - 0s 173us/step - loss: 0.0090 - mean_absolute_error: 0.0733 - mean_squared_error: 0.0090 - val_loss: 0.0090 - val_mean_absolute_error: 0.0695 - val_mean_squared_error: 0.0090
# Epoch 93/100
# 167/167 [==============================] - 0s 154us/step - loss: 0.0087 - mean_absolute_error: 0.0720 - mean_squared_error: 0.0087 - val_loss: 0.0074 - val_mean_absolute_error: 0.0671 - val_mean_squared_error: 0.0074
# Epoch 94/100
# 167/167 [==============================] - 0s 196us/step - loss: 0.0097 - mean_absolute_error: 0.0769 - mean_squared_error: 0.0097 - val_loss: 0.0091 - val_mean_absolute_error: 0.0708 - val_mean_squared_error: 0.0091
# Epoch 95/100
# 167/167 [==============================] - 0s 283us/step - loss: 0.0091 - mean_absolute_error: 0.0740 - mean_squared_error: 0.0091 - val_loss: 0.0076 - val_mean_absolute_error: 0.0661 - val_mean_squared_error: 0.0076
# Epoch 96/100
# 167/167 [==============================] - 0s 236us/step - loss: 0.0087 - mean_absolute_error: 0.0724 - mean_squared_error: 0.0087 - val_loss: 0.0079 - val_mean_absolute_error: 0.0674 - val_mean_squared_error: 0.0079
# Epoch 97/100
# 167/167 [==============================] - 0s 245us/step - loss: 0.0087 - mean_absolute_error: 0.0719 - mean_squared_error: 0.0087 - val_loss: 0.0080 - val_mean_absolute_error: 0.0670 - val_mean_squared_error: 0.0080
# Epoch 98/100
# 167/167 [==============================] - 0s 200us/step - loss: 0.0090 - mean_absolute_error: 0.0733 - mean_squared_error: 0.0090 - val_loss: 0.0080 - val_mean_absolute_error: 0.0665 - val_mean_squared_error: 0.0080
# Epoch 99/100
# 167/167 [==============================] - 0s 205us/step - loss: 0.0087 - mean_absolute_error: 0.0729 - mean_squared_error: 0.0087 - val_loss: 0.0077 - val_mean_absolute_error: 0.0662 - val_mean_squared_error: 0.0077
# Epoch 100/100
# 167/167 [==============================] - 0s 225us/step - loss: 0.0085 - mean_absolute_error: 0.0703 - mean_squared_error: 0.0085 - val_loss: 0.0085 - val_mean_absolute_error: 0.0676 - val_mean_squared_error: 0.0085

# %%
# Выводим динамику среднего абсолютного отклонения от номера эпохи обучения.
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error']) 
plt.title('Model MAE') 
plt.ylabel('MAE') 
plt.xlabel('Epoch') 
plt.legend(['Train', 'Test'], loc='upper right') 
plt.show()

# %%
# Выводим динамику среднеквадратического отклонения, т.е. значения функции потерь, от номера эпохи обучения.
# Видно, что в процессе обучения сеть с каждой эпохой вычисляет всё более точные прогнозы значений Y.
plt.plot(history.history['mean_squared_error'])
plt.plot(history.history['val_mean_squared_error']) 
plt.title('Model MSE') 
plt.ylabel('MSE') 
plt.xlabel('Epoch') 
plt.legend(['Train', 'Test'], loc='upper right') 
plt.show()

# %%
# Предсказание уже обученной нейронной сети на обучающей выборке:
Y_pred_train = model.predict(X_train).flatten()

# %%
# Сравним эталонные значения Y_train и результат работы обученной нейронной сети Y_pred_train для обучающей выборки.
# В идеальной ситуации они должны совпадать, т.е. точки (Y_train[i], Y_pred_train[i]) должны лежать на прямой Y_train = Y_pred_train.
plt.plot(Y_train, Y_pred_train, 'bo')
plt.plot([0,1], [0,1], 'r-')
plt.title('Test vs Pred_test') 
plt.ylabel('Pred_test') 
plt.xlabel('Test') 
plt.show()

# %%
# Выведем сами значения Y_train и Y_pred_train.
plt.plot(Y_train)
plt.plot(Y_pred_train)
plt.show()

# %%
# Таким образом, обучение по обучающей выборке проведено.
# Теперь проверим работу нейроной сети на тестовой выборке.

# Предсказание обученной нейронной сети на тестовой выборке:
Y_pred_test = model.predict(X_test).flatten()

# %%
# Сравним эталонные значения Y_test и результат работы обученной нейронной сети Y_pred_test для тестовой выборки.
plt.plot(Y_test, Y_pred_test, 'bo')
plt.plot([0,1], [0,1], 'r-')
plt.title('Test vs Pred_test') 
plt.ylabel('Pred_test') 
plt.xlabel('Test') 
plt.show()

# %%
# Выведем сами значения Y_test и Y_pred_test.
plt.plot(Y_test)
plt.plot(Y_pred_test)
plt.show()

# %%
# Итого, качество работы нейронной сети на тестовых данных ниже, чем на обучающих - это ожидаемо.
# Тем не менее, нейронная сеть способна найти зависимости и предсказвать значение Y по X с приемлемым уровенм точности.

# Сравним среднеквадратичные ошибки (значения функции потерь) для обучающей и тестовой выборок.
print(numpy.sqrt(mean_squared_error(Y_train, Y_pred_train)))
print(numpy.sqrt(mean_squared_error(Y_test, Y_pred_test)))
# Out:
# 0.09193047273872866
# 0.09204586634378263

# %%
# Проверим на нормальное распределение разности пар (Y_train, Y_pred_train), (Y_test, Y_pred_test)
# Для этого используем библиотеку scipy и метод stats.shapiro.
k_train, p_train = stats.shapiro(Y_train - Y_pred_train)
print('Train k = {0}, p = {1}'.format(k_train, p_train))

k_test, p_test = stats.shapiro(Y_test - Y_pred_test)
print('Test k = {0}, p = {1}'.format(k_test, p_test))
# Out:
# Train k = 0.9895468950271606, p = 0.25566670298576355
# Test k = 0.9762228727340698, p = 0.5205116868019104

# %%
# Для полной выборки (Y, Y_pred) применим два статистических теста: shapiro и normaltest.
Y_pred = model.predict(X).flatten()

k_s, p_s = stats.shapiro(Y - Y_pred)
print('k_s = {0}, p_s = {1}'.format(k_s, p_s))

k_n, p_n = stats.normaltest(Y - Y_pred)
print('k_n = {0}, p_n = {1}'.format(k_n, p_n))
# Out:
# k_s = 0.9904346466064453, p_s = 0.18182773888111115
# k_n = 4.3572322840247795, p_n = 0.11319807235632799

# %%
# И тоже самое визуально, с помощью грфиков квантиль-квантиль.
# Обучающая выборка
qqplot(Y_train - Y_pred_train)
plt.show()

# %%
# Тестовая выборка
qqplot(Y_test - Y_pred_test)
plt.show()

# %%
# Полная выборка
qqplot(Y - Y_pred)
plt.show()

# %%
# Можо также визульно убедиться, что распределения "почти нормальное".
plt.hist(Y - Y_pred, bins=50)
plt.show()

# %%
# Сохраним обученную нейронную сеть, название файла можно выбрать любое, расширение - h5.
model.save('SimpleNeuralNetwork.h5')
